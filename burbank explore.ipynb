# %%
import pandas as pd

# %%
burbank = pd.read_csv("burbank.csv")

# %%
#print top of document
burbank.head()
# Out:
#       ZIPcode TaxRateArea_CITY         AIN  RollYear  TaxRateArea  \
# 0  91501-1106      BURBANK      5608002004      2017         2530
# 1  91501-1106      BURBANK      5608002005      2017         2530
# 2  91501-1106      BURBANK      5608002006      2017         2530
# 3  91501-1106      BURBANK      5608002007      2017         2530
# 4  91501-1106      BURBANK      5608002008      2017         2530
#
#      AssessorID                   PropertyLocation PropertyType  \
# 0  5608-002-004  1856 AYERS WAY  BURBANK CA  91501          SFR
# 1  5608-002-005  1852 AYERS WAY  BURBANK CA  91501          SFR
# 2  5608-002-006  1848 AYERS WAY  BURBANK CA  91501          SFR
# 3  5608-002-007  1844 AYERS WAY  BURBANK CA  91501          SFR
# 4  5608-002-008  1840 AYERS WAY  BURBANK CA  91501          SFR
#
#   PropertyUseCode GeneralUseType              ...              HouseFraction  \
# 0             100    Residential              ...
# 1             100    Residential              ...
# ...

# %%
# print details of columns
burbank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28072 entries, 0 to 28071
# Data columns (total 51 columns):
# ZIPcode                        28072 non-null object
# TaxRateArea_CITY               28072 non-null object
# AIN                            28072 non-null int64
# RollYear                       28072 non-null int64
# TaxRateArea                    28072 non-null int64
# AssessorID                     28072 non-null object
# PropertyLocation               28072 non-null object
# PropertyType                   28072 non-null object
# PropertyUseCode                28072 non-null object
# GeneralUseType                 28072 non-null object
# SpecificUseType                28072 non-null object
# SpecificUseDetail1             28072 non-null object
# SpecificUseDetail2             28072 non-null object
# totBuildingDataLines           28072 non-null int64
# YearBuilt                      28072 non-null int64
# EffectiveYearBuilt             28072 non-null int64
# ...

# %%
# access a column
burbank.AIN
# Out:
# 0        5608002004
# 1        5608002005
# 2        5608002006
# 3        5608002007
# 4        5608002008
# 5        5608002009
# 6        5608002010
# 7        5608002011
# 8        5608002012
# 9        5608002013
# 10       5608002014
# 11       5608002015
# 12       5608002016
# 13       5608002017
# 14       5608002018
# 15       5608002019
# 16       5608002020
# 17       5608002021
# 18       5608002022
# 19       5608002023
# 20       5608002030
# 21       5608002031
# 22       5608002032
# 23       5608002033
# 24       5608002034
# 25       5608002035
# 26       5608002036
# 27       5608002037
# 28       5608002038
# 29       5608002039
#             ...
# 28042    2485028030
# 28043    2485028031
# 28044    2485028032
# 28045    2485028033
# 28046    2485029001
# 28047    2485029002
# 28048    2485029003
# 28049    2485029004
# 28050    2485029005
# 28051    2485029006
# 28052    2485029007
# 28053    2485029008
# 28054    2485029009
# 28055    2485029010
# ...

# %%
# spit out counts for values
burbank.EffectiveYearBuilt.value_counts()
# Out:
# 1950    1076
# 1941    1052
# 1940     915
# 1951     860
# 1947     825
# 1944     821
# 1948     798
# 1952     787
# 1942     761
# 1980     750
# 1953     728
# 1955     727
# 1939     644
# 1954     643
# 1943     611
# 1949     608
# 1945     587
# 1960     567
# 1946     564
# 1990     552
# 1981     507
# 1965     479
# 1956     475
# 1957     414
# 1970     413
# 1938     390
# 1964     388
# 1958     363
# 1963     351
# 1962     339
#         ...
# 1933      66
# 1924      65
# 1993      61
# 1994      60
# 1934      56
# 1996      39
# 1998      36
# 1923      34
# 1997      30
# 2010      28
# 2011      23
# 2014      23
# 2015      22
# 1922      21
# 2012      14
# 1920      12
# 2013      11
# 1921      10
# 1918       5
# 2016       5
# 1910       4
# 1900       3
# 1916       3
# 1915       2
# 1914       2
# 1913       2
# 1911       1
# 1908       1
# 1887       1
# 2017       1
# Name: EffectiveYearBuilt, Length: 109, dtype: int64

# %%
# spit out counts for values but in clean format
burbank.EffectiveYearBuilt.value_counts().reset_index()
# Out:
#      index  EffectiveYearBuilt
# 0     1950                1076
# 1     1941                1052
# 2     1940                 915
# 3     1951                 860
# 4     1947                 825
# 5     1944                 821
# 6     1948                 798
# 7     1952                 787
# 8     1942                 761
# 9     1980                 750
# 10    1953                 728
# 11    1955                 727
# 12    1939                 644
# 13    1954                 643
# 14    1943                 611
# 15    1949                 608
# 16    1945                 587
# 17    1960                 567
# 18    1946                 564
# 19    1990                 552
# 20    1981                 507
# 21    1965                 479
# 22    1956                 475
# 23    1957                 414
# 24    1970                 413
# 25    1938                 390
# 26    1964                 388
# 27    1958                 363
# 28    1963                 351
# ...

# %%
# filter only to properties built in 1950
burbank1950 = burbank[burbank.EffectiveYearBuilt == 1950]

# %%
# setting to display all columns
pd.options.display.max_columns = None

# %%
burbank1950.head()
# Out:
#         ZIPcode TaxRateArea_CITY         AIN  RollYear  TaxRateArea  \
# 109  91501-1111      BURBANK      5608019015      2017         2530
# 113  91501-1004      BURBANK      5608020005      2017         2530
# 188  91501-1137      BURBANK      5608026005      2017         2530
# 260  91501-1105      BURBANK      5608030007      2017         2530
# 338  91501-1661      BURBANK      5608035015      2017         2530
#
#        AssessorID                           PropertyLocation PropertyType  \
# 109  5608-019-015     111 COUNTRY CLUB DR  BURBANK CA  91501          SFR
# 113  5608-020-005      3 ORANGE GROVE TER  BURBANK CA  91501          SFR
# 188  5608-026-005      1207 E TUJUNGA AVE  BURBANK CA  91501          SFR
# 260  5608-030-007  318 S SUNSET CANYON DR  BURBANK CA  91501          SFR
# 338  5608-035-015             640 VIEW DR  BURBANK CA  91501          SFR
#
#     PropertyUseCode GeneralUseType          SpecificUseType  \
# ...

# %%
burbank1950.to_csv("b1950.csv")
